# %% [markdown]
# <a href="https://colab.research.google.com/github/yagnesh2004/Python/blob/main/Finetune_DistilBERT_PDF_Question_and_Answering.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install transformers
from transformers import AutoTokenizer, AutoModelForQuestionAnswering, pipeline

# Load pre-trained tokenizer and model for question-answering
tokenizer = AutoTokenizer.from_pretrained("distilbert-base-cased-distilled-squad")
model = AutoModelForQuestionAnswering.from_pretrained("distilbert-base-cased-distilled-squad")
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.1/7.1 MB 28.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 224.5/224.5 kB 11.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 58.0 MB/s eta 0:00:00
# ...

# %%
# !pip install PyPDF2
# !pip install pdfminer-six

import PyPDF2

#from pdfminer.high_level import extract_text
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 232.6/232.6 kB 10.2 MB/s eta 0:00:00
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 63.1 MB/s eta 0:00:00
# ...

# %%
import torch
from transformers import DistilBertTokenizer, DistilBertForQuestionAnswering
from pdfminer.high_level import extract_text


# Get the PDF filename from the user
pdf_filename ="/content/Bluetooth Security.pdf"


# Extract the text from the PDF document
context = extract_text(pdf_filename)

# Get the question from the user
question = input("Ask a question about the PDF document: ")


# Use pipeline to generate answer
nlp = pipeline('question-answering', model=model, tokenizer=tokenizer)
result = nlp(question=question, context=context)

# Print answer
print(result["answer"])
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-3-13776dd2d601> in <cell line: 3>()
#       1 import torch
#       2 from transformers import DistilBertTokenizer, DistilBertForQuestionAnswering
# ----> 3 from pdfminer.high_level import extract_text
#       4
#       5
#
# ModuleNotFoundError: No module named 'pdfminer'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
# Get the question from the user
question = input("Ask a question about the PDF document: ")


# Use pipeline to generate answer
nlp = pipeline('question-answering', model=model, tokenizer=tokenizer)
result = nlp(question=question, context=context)

# Print answer
print(result["answer"])
# Out:
# Ask a question about the PDF document: what is pdf
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-429b710802cc> in <cell line: 7>()
#       5 # Use pipeline to generate answer
#       6 nlp = pipeline('question-answering', model=model, tokenizer=tokenizer)
# ----> 7 result = nlp(question=question, context=context)
#       8
#       9 # Print answer
#
# NameError: name 'context' is not defined
